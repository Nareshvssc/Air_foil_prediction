# %%
import pandas as pd

# %%
df= pd.read_csv('airfoil_self_noise.dat',delimiter="\t",names=['Frequency','Angle of attack','Chord length', 'Free-stream velocity','displacement_thickness','Pressure_level'])

# %%
df.head()
# Out:
#    Frequency  Angle of attack  Chord length  Free-stream velocity  \
# 0        800              0.0        0.3048                  71.3
# 1       1000              0.0        0.3048                  71.3
# 2       1250              0.0        0.3048                  71.3
# 3       1600              0.0        0.3048                  71.3
# 4       2000              0.0        0.3048                  71.3
#
#    displacement_thickness  Pressure_level
# 0                0.002663         126.201
# 1                0.002663         125.201
# 2                0.002663         125.951
# 3                0.002663         127.591
# 4                0.002663         127.461

# %%
df.dtypes
# Out:
# Frequency                   int64
# Angle of attack           float64
# Chord length              float64
# Free-stream velocity      float64
# displacement_thickness    float64
# Pressure_level            float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Frequency                 0
# Angle of attack           0
# Chord length              0
# Free-stream velocity      0
# displacement_thickness    0
# Pressure_level            0
# dtype: int64

# %%
### First Do the train test split

# %%
X = df.iloc[:,:-1]
y= df.iloc[:,-1]

# %%
y
# Out:
# 0       126.201
# 1       125.201
# 2       125.951
# 3       127.591
# 4       127.461
#          ...
# 1498    110.264
# 1499    109.254
# 1500    106.604
# 1501    106.224
# 1502    104.204
# Name: Pressure_level, Length: 1503, dtype: float64

# %%
import seaborn as sns

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3)

# %%
sns.pairplot(X_train)

# %%
import matplotlib.pyplot as plt
X_train.corr()
# Out:
#                         Frequency  Angle of attack  Chord length  \
# Frequency                1.000000        -0.267240     -0.045397
# Angle of attack         -0.267240         1.000000     -0.511291
# Chord length            -0.045397        -0.511291      1.000000
# Free-stream velocity     0.120482         0.067424     -0.014677
# displacement_thickness  -0.235980         0.764505     -0.238191
#
#                         Free-stream velocity  displacement_thickness
# Frequency                           0.120482               -0.235980
# Angle of attack                     0.067424                0.764505
# Chord length                       -0.014677               -0.238191
# Free-stream velocity                1.000000                0.011755
# displacement_thickness              0.011755                1.000000

# %%
import pandas_profiling as Pp

# %%
Pp.ProfileReport(df)
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.1.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2022-05-28 06:37:20.020003&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
for i in X_train.columns:
    sns.boxplot(i,data=X_train)
# Out:
# C:\Users\nares\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\nares\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\nares\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
plt.scatter(x=X_train['Frequency'],y=y_train)

# %%
df['Pressure_level'].unique()
# Out:
# array([126.201, 125.201, 125.951, ..., 106.604, 106.224, 104.204])

# %%
sns.boxplot(y='Pressure_level',data=df)
# Out:
# <AxesSubplot:ylabel='Pressure_level'>

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.fit_transform(X_test)

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.linear_model import Ridge

# %%
params = {'solver':['auto', 'svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga'],'alpha':[1,2,3,0.1,0.2]}

# %%
lin_regmodel = Ridge()
lin_regmodelgrid = GridSearchCV(lin_regmodel,params)
lin_regmodelgrid.fit(X_train,y_train)
# Out:
# GridSearchCV(estimator=Ridge(),
#              param_grid={'alpha': [1, 2, 3, 0.1, 0.2],
#                          'solver': ['auto', 'svd', 'cholesky', 'lsqr',
#                                     'sparse_cg', 'sag', 'saga']})

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

# %%
mean_absolute_error(y_train,lin_regmodelgrid.predict(X_train))
# Out:
# 3.7933680211713376

# %%
r2_score(y_train,lin_regmodelgrid.predict(X_train))
# Out:
# 0.48187782352397357

# %%
import pickle
pickle.dump(lin_regmodelgrid,open('model.pkl','wb'))

# %% [markdown]
# ### using Linear regression 3.877 mean absoulte error  and r2_score is 0.486

# %%
pickle_load  =pickle.load(open('model.pkl','rb'))

# %%
#batch input
pickle_load.predict(X_test_scaled)
# Out:
# array([185.60465757,  84.8106012 , 208.97245324, 218.40456808,
#         92.61108784, 127.79399394, 220.93168324, 126.24801796,
#        180.71201723, 162.83263677,  86.2260672 ,  96.09051523,
#        203.77547305, 206.0359905 , 221.08397725, 140.66287844,
#        184.73412814, 126.25041125, 182.59036754, 149.87430558,
#         24.16474204, 155.45804181,  98.82774491, 220.66919917,
#         82.78739212, 103.14416425, 205.13635382, 120.59817927,
#        151.38611463, 171.38951078, 190.36508782,  24.16633757,
#        189.6550864 , 184.73186648, 169.80508268,  44.26735894,
#         95.90809919,  89.16988508, 220.93327877,  16.80349153,
#         88.34978699, 126.99754391, 167.23995075,  90.43266606,
#        188.70581715, 204.55046205,  89.16972552, 139.37146371,
#         44.26620219, 220.92849218, 218.84817134,  68.74990974,
#         93.81177597,  56.38806508, 189.65501859, 166.60140358,
#        208.61568617,  84.81072086, 185.60685142, -22.18676614,
# ...

# %%
df.loc[51]
# Out:
# Frequency                 400.000000
# Angle of attack             0.000000
# Chord length                0.304800
# Free-stream velocity       31.700000
# displacement_thickness      0.003313
# Pressure_level            125.045000
# Name: 51, dtype: float64

# %%
dict_values ={'Frequency':400.000000,
'Angle of attack':0.000000,
'Chord length':0.304800,
'Free-stream velocity':31.700000,
'displacement_thickness':0.003313,
'Pressure_level':125.045000,}

# %%
one_input = list(dict_values.values())
one_input
# Out:
# [400.0, 0.0, 0.3048, 31.7, 0.003313, 125.045]

# %%
pickle_load.predict(one_input.reshape(-1,1))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-c2d0c3c1b467> in <module>
# ----> 1 pickle_load.predict(one_input.reshape(-1,1))
#
# AttributeError: 'list' object has no attribute 'reshape'

# %%
from sklearn.svm import SVR

# %%
params = {'kernel':['poly','rbf'],'degree':[3,4,5,6]}
svr_model = SVR()
grid_regree = GridSearchCV(svr_model,params)

# %%
grid_regree.fit(X_train,y_train)

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
tree_reg = DecisionTreeRegressor(max_depth=4)
tree_reg.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=4)

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
KNeigbors_model = KNeighborsRegressor()

# %%
KNeigbors_model.fit(X_train,y_train)
# Out:
# KNeighborsRegressor()
